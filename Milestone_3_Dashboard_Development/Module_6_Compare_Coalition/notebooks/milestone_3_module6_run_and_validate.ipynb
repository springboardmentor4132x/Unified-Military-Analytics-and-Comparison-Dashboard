# %% [markdown]
# # Module 6 — Coalition: Run & Validation
#
# Instructions for running and validating Module 6 dashboard apps (Streamlit / Tableau / Power BI integration).

# %% [markdown]
# ## Run commands (local)
# - Streamlit coalition apps:
# ```bash
# cd Milestone_3_Dashboard_Development/Module_6_Compare_Coalition/dashboards/streamlit
# streamlit run compare_powers_app.py
# ```
# - Coalition builder:
# ```bash
# streamlit run coalition_builder_app.py
# ```
# - Tableau: open workbook and point to `military_final_wide.csv`

# %%
import pandas as pd
from pathlib import Path

candidates = [
    Path('..') / 'data' / 'processed' / 'military_final_wide.csv',
    Path('..') / '..' / '..' / 'Milestone_2_KPI_Engineering' / 'Module_3_KPI_Engineering' / 'data' / 'processed' / 'military_final_wide.csv'
]
for p in candidates:
    if p.exists():
        print('Found:', p)
        df = pd.read_csv(p)
        print('Rows,Cols:', df.shape)
        display(df[['country','power_rank','power_index']].head())
        break
else:
    print('No KPI CSV found; copy M2 outputs first.')

# %% [markdown]
# ## Validation checklist
# - [ ] Confirm coalition aggregation matches expected sums for personnel and budgets.
# - [ ] Verify filter interactions in the compare app (multi-select behaviour).
# - [ ] Verify Tableau workbook connections and update extracts if any.
# - [ ] Capture screenshots of main views for the delivery package.
